# %% [markdown]
# # Phase 5: Power Analysis
# Sample size and multiple testing correction.

# %%
import sys
sys.path.append("../src")
from power_analysis import calculate_sample_size, apply_multiple_testing_correction

# %%
n = calculate_sample_size(0.10, 0.02, alpha=0.05, power=0.8, is_proportion=True)
print(f"Required Sample Size per group: {n}")

# %%
p_vals = [0.01, 0.04, 0.06, 0.20, 0.001]
reject, corrected = apply_multiple_testing_correction(p_vals, method="fdr")
print("FDR Corrected:", corrected)
print("Significant:", reject)
