# %% [markdown]
# # Phase 4: Sequential Testing
# Methods for early stopping.

# %%
import sys
sys.path.append("../src")
from sequential_tests import sprt
import numpy as np

# %%
np.random.seed(42)
data_a = np.random.binomial(1, 0.10, 5000)
data_b = np.random.binomial(1, 0.13, 5000)

res = sprt(data_a, data_b, mde=0.03)
print(res)
